# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.random.randn(10000)
x
# Out:
# array([-0.67118495,  0.79495055,  0.44814233, ..., -0.26408984,
#         0.80808638, -1.25988941], shape=(10000,))

# %%
plt.hist(x,bins=20,color='red',edgecolor='black',alpha=1)
plt.show()

# %%
x =  np.random.randint(100,500,50)
x
# Out:
# array([473, 177, 242, 309, 209, 374, 423, 365, 165, 242, 449, 148, 219,
#        386, 230, 221, 155, 363, 194, 206, 204, 182, 347, 385, 498, 203,
#        354, 170, 173, 273, 486, 352, 162, 260, 173, 279, 196, 107, 154,
#        304, 228, 435, 256, 272, 448, 437, 286, 199, 114, 386], dtype=int32)

# %%
plt.boxplot(x)
plt.show()
